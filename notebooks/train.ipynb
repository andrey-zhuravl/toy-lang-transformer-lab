# %% [markdown]
# # Training demo
# This notebook demonstrates how to train the toy transformer using the high level trainer script.

# %%
import yaml
from pathlib import Path
from src.trainer import train_loop

config_path = Path('src/config.yaml')
config = yaml.safe_load(config_path.read_text())
train_loop(config)
